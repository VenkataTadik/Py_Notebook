# %% [markdown]
# <a href="https://colab.research.google.com/github/VenkataTadik/Py_Notebook/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-xcx7051t
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-xcx7051t
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.4.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=350eb6a5897beab912f19abb3cebd7c7746c78c4ec9b5f073deed3808b427ed7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7te9bgcy/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    h1 = self.linear1(x)
    h2 = self.linear2(h1.relu()) + h1
    h3 = self.linear3(h2.relu()) + h2
    return self.linear4(h3.relu())

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.586633, train error 62.65,  val loss 1.654743, percent error 68.80
# Epoch     1, train loss 1.298646, train error 49.28,  val loss 1.455570, percent error 57.10
# Epoch     2, train loss 1.120471, train error 42.22,  val loss 1.344795, percent error 53.90
# Epoch     3, train loss 0.985332, train error 35.97,  val loss 1.280354, percent error 49.50
# Epoch     4, train loss 0.805583, train error 28.95,  val loss 1.171377, percent error 44.70
# Epoch     5, train loss 0.703897, train error 25.07,  val loss 1.106212, percent error 43.50
# Epoch     6, train loss 0.656593, train error 23.97,  val loss 1.186189, percent error 44.80
# Epoch     7, train loss 0.524766, train error 18.65,  val loss 1.088509, percent error 39.00
# Epoch     8, train loss 0.433643, train error 14.57,  val loss 1.119996, percent error 40.50
# Epoch     9, train loss 0.438318, train error 15.82,  val loss 1.142255, percent error 38.20
# Epoch    10, train loss 0.348612, train error 11.78,  val loss 1.172595, percent error 39.50
# Epoch    11, train loss 0.294970, train error 9.97,  val loss 1.150032, percent error 39.00
# Epoch    12, train loss 0.236071, train error 7.43,  val loss 1.194527, percent error 36.90
# Epoch    13, train loss 0.205668, train error 6.45,  val loss 1.222200, percent error 35.90
# Epoch    14, train loss 0.223822, train error 7.20,  val loss 1.413167, percent error 38.40
# Epoch    15, train loss 0.223454, train error 7.80,  val loss 1.377209, percent error 38.40
# Epoch    16, train loss 0.180007, train error 5.57,  val loss 1.427590, percent error 38.70
# Epoch    17, train loss 0.186205, train error 5.47,  val loss 1.540786, percent error 39.60
# Epoch    18, train loss 0.172045, train error 5.53,  val loss 1.500053, percent error 37.70
# Epoch    19, train loss 0.120642, train error 3.70,  val loss 1.505309, percent error 36.60
# Epoch    20, train loss 0.042874, train error 0.35,  val loss 1.368024, percent error 35.90
# Epoch    21, train loss 0.025057, train error 0.10,  val loss 1.381668, percent error 34.30
# Epoch    22, train loss 0.018575, train error 0.03,  val loss 1.394644, percent error 33.80
# Epoch    23, train loss 0.015314, train error 0.00,  val loss 1.428000, percent error 34.10
# Epoch    24, train loss 0.013018, train error 0.00,  val loss 1.456838, percent error 34.30
# Epoch    25, train loss 0.011503, train error 0.00,  val loss 1.478199, percent error 34.20
# Epoch    26, train loss 0.010306, train error 0.00,  val loss 1.493819, percent error 33.70
# Epoch    27, train loss 0.009455, train error 0.00,  val loss 1.514381, percent error 33.90
# Epoch    28, train loss 0.008588, train error 0.00,  val loss 1.530002, percent error 33.60
# Epoch    29, train loss 0.007923, train error 0.00,  val loss 1.543882, percent error 33.70
# Epoch    30, train loss 0.007422, train error 0.00,  val loss 1.556584, percent error 33.40
# Epoch    31, train loss 0.006942, train error 0.00,  val loss 1.572250, percent error 33.60
# Epoch    32, train loss 0.006470, train error 0.00,  val loss 1.585686, percent error 33.60
# Epoch    33, train loss 0.006091, train error 0.00,  val loss 1.600872, percent error 33.70
# Epoch    34, train loss 0.005752, train error 0.00,  val loss 1.608999, percent error 33.40
# Epoch    35, train loss 0.005461, train error 0.00,  val loss 1.622728, percent error 33.50
# Epoch    36, train loss 0.005195, train error 0.00,  val loss 1.633408, percent error 33.70
# Epoch    37, train loss 0.004925, train error 0.00,  val loss 1.639641, percent error 33.60
# Epoch    38, train loss 0.004700, train error 0.00,  val loss 1.650696, percent error 33.30
# Epoch    39, train loss 0.004494, train error 0.00,  val loss 1.659293, percent error 33.70
# Epoch    40, train loss 0.004388, train error 0.00,  val loss 1.665245, percent error 33.70
# Epoch    41, train loss 0.004296, train error 0.00,  val loss 1.668750, percent error 33.80
# Epoch    42, train loss 0.004210, train error 0.00,  val loss 1.673534, percent error 33.50
# Epoch    43, train loss 0.004127, train error 0.00,  val loss 1.676950, percent error 33.90
# Epoch    44, train loss 0.004046, train error 0.00,  val loss 1.681860, percent error 33.70
# Epoch    45, train loss 0.003968, train error 0.00,  val loss 1.685845, percent error 33.90
# Epoch    46, train loss 0.003892, train error 0.00,  val loss 1.688896, percent error 33.90
# Epoch    47, train loss 0.003821, train error 0.00,  val loss 1.693560, percent error 33.80
# Epoch    48, train loss 0.003752, train error 0.00,  val loss 1.696760, percent error 33.90
# Epoch    49, train loss 0.003686, train error 0.00,  val loss 1.699190, percent error 33.90
# Epoch    50, train loss 0.003621, train error 0.00,  val loss 1.703845, percent error 33.80
# Epoch    51, train loss 0.003558, train error 0.00,  val loss 1.706540, percent error 33.90
# Epoch    52, train loss 0.003498, train error 0.00,  val loss 1.711068, percent error 33.80
# Epoch    53, train loss 0.003440, train error 0.00,  val loss 1.714254, percent error 33.70
# Epoch    54, train loss 0.003384, train error 0.00,  val loss 1.716152, percent error 33.80
# Epoch    55, train loss 0.003328, train error 0.00,  val loss 1.720007, percent error 33.80
# Epoch    56, train loss 0.003275, train error 0.00,  val loss 1.723096, percent error 33.50
# Epoch    57, train loss 0.003223, train error 0.00,  val loss 1.726986, percent error 33.50
# Epoch    58, train loss 0.003173, train error 0.00,  val loss 1.729745, percent error 33.50
# Epoch    59, train loss 0.003124, train error 0.00,  val loss 1.733547, percent error 33.70
# Epoch    60, train loss 0.003099, train error 0.00,  val loss 1.734681, percent error 33.60
# Epoch    61, train loss 0.003075, train error 0.00,  val loss 1.736628, percent error 33.50
# Epoch    62, train loss 0.003052, train error 0.00,  val loss 1.738273, percent error 33.50
# Epoch    63, train loss 0.003029, train error 0.00,  val loss 1.739721, percent error 33.50
# Epoch    64, train loss 0.003007, train error 0.00,  val loss 1.740548, percent error 33.50
# Epoch    65, train loss 0.002985, train error 0.00,  val loss 1.742828, percent error 33.50
# Epoch    66, train loss 0.002963, train error 0.00,  val loss 1.743811, percent error 33.60
# Epoch    67, train loss 0.002942, train error 0.00,  val loss 1.745586, percent error 33.50
# Epoch    68, train loss 0.002921, train error 0.00,  val loss 1.747016, percent error 33.50
# Epoch    69, train loss 0.002900, train error 0.00,  val loss 1.748438, percent error 33.60
# Epoch    70, train loss 0.002879, train error 0.00,  val loss 1.750067, percent error 33.70
# Epoch    71, train loss 0.002859, train error 0.00,  val loss 1.750478, percent error 33.50
# Epoch    72, train loss 0.002839, train error 0.00,  val loss 1.752800, percent error 33.60
# Epoch    73, train loss 0.002820, train error 0.00,  val loss 1.754245, percent error 33.50
# Epoch    74, train loss 0.002800, train error 0.00,  val loss 1.755390, percent error 33.60
# Epoch    75, train loss 0.002781, train error 0.00,  val loss 1.756626, percent error 33.60
# Epoch    76, train loss 0.002762, train error 0.00,  val loss 1.758499, percent error 33.60
# Epoch    77, train loss 0.002743, train error 0.00,  val loss 1.759428, percent error 33.50
# Epoch    78, train loss 0.002724, train error 0.00,  val loss 1.760782, percent error 33.50
# Epoch    79, train loss 0.002706, train error 0.00,  val loss 1.762483, percent error 33.60
# Epoch    80, train loss 0.002697, train error 0.00,  val loss 1.763065, percent error 33.60
# Epoch    81, train loss 0.002688, train error 0.00,  val loss 1.763695, percent error 33.60
# Epoch    82, train loss 0.002679, train error 0.00,  val loss 1.764416, percent error 33.60
# Epoch    83, train loss 0.002670, train error 0.00,  val loss 1.765269, percent error 33.60
# Epoch    84, train loss 0.002661, train error 0.00,  val loss 1.765802, percent error 33.60
# Epoch    85, train loss 0.002653, train error 0.00,  val loss 1.766587, percent error 33.50
# Epoch    86, train loss 0.002644, train error 0.00,  val loss 1.767167, percent error 33.60
# Epoch    87, train loss 0.002636, train error 0.00,  val loss 1.767940, percent error 33.60
# Epoch    88, train loss 0.002627, train error 0.00,  val loss 1.768474, percent error 33.60
# Epoch    89, train loss 0.002618, train error 0.00,  val loss 1.769089, percent error 33.50
# Epoch    90, train loss 0.002610, train error 0.00,  val loss 1.769578, percent error 33.50
# Epoch    91, train loss 0.002602, train error 0.00,  val loss 1.770437, percent error 33.50
# Epoch    92, train loss 0.002593, train error 0.00,  val loss 1.771173, percent error 33.50
# Epoch    93, train loss 0.002585, train error 0.00,  val loss 1.771776, percent error 33.50
# Epoch    94, train loss 0.002577, train error 0.00,  val loss 1.772405, percent error 33.50
# Epoch    95, train loss 0.002569, train error 0.00,  val loss 1.773073, percent error 33.50
# Epoch    96, train loss 0.002560, train error 0.00,  val loss 1.773511, percent error 33.50
# Epoch    97, train loss 0.002552, train error 0.00,  val loss 1.774391, percent error 33.50
# Epoch    98, train loss 0.002544, train error 0.00,  val loss 1.774953, percent error 33.50
# Epoch    99, train loss 0.002536, train error 0.00,  val loss 1.775689, percent error 33.50

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
